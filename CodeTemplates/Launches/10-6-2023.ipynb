# %%
import pandas as pd
import seaborn as sns
import requests
from io import StringIO

# %%
def getResponse(page):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page"+str(page)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NDc2YzcxMzAxNjE5YzI3YzVkNjQyMDMyNjI2NDE0MCIsInN1YiI6IjY1MWQ4OWViYzUwYWQyMDEyYzFiNGE5OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.zR8rCPY9jYYKJNzKrx29CCsZz_ELmxqdPjDOVMm7qx0"
    }

    response = requests.get(url, headers=headers)

    return response.json()['results']

# %%
for i in range(50, 61):
    response = getResponse(i+1)
    for movieData in response:
        print(len(movieData), movieData['release_date'])
        if movieData["release_date"].split("-")[0] == "2022":
            print(movieData['title'])
# Out:
# 14 1972-03-14
# 14 1994-09-23
# 14 1974-12-20
# 14 1993-12-15
# 14 1995-10-20
# 14 1957-04-10
# 14 2001-07-20
# 14 2019-05-30
# 14 2016-08-26
# 14 2008-07-16
# 14 1999-12-10
# 14 1994-09-10
# 14 1994-06-23
# 14 2003-12-01
# 14 1966-12-23
# 14 1990-09-12
# 14 1988-04-16
# 14 1997-12-20
# 14 1954-04-26
# 14 1988-11-17
# 14 1972-03-14
# 14 1994-09-23
# 14 1974-12-20
# 14 1993-12-15
# 14 1995-10-20
# 14 1957-04-10
# 14 2001-07-20
# 14 2019-05-30
# 14 2016-08-26
# 14 2008-07-16
# 14 1999-12-10
# 14 1994-09-10
# 14 1994-06-23
# 14 2003-12-01
# 14 1966-12-23
# 14 1990-09-12
# 14 1988-04-16
# 14 1997-12-20
# 14 1954-04-26
# 14 1988-11-17
# 14 1972-03-14
# 14 1994-09-23
# 14 1974-12-20
# 14 1993-12-15
# 14 1995-10-20
# 14 1957-04-10
# 14 2001-07-20
# 14 2019-05-30
# 14 2016-08-26
# 14 2008-07-16
# 14 1999-12-10
# 14 1994-09-10
# 14 1994-06-23
# 14 2003-12-01
# 14 1966-12-23
# 14 1990-09-12
# 14 1988-04-16
# 14 1997-12-20
# 14 1954-04-26
# 14 1988-11-17
# 14 1972-03-14
# 14 1994-09-23
# ...
