# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://en.wikipedia.org/wiki/List_of_potato_museums'

# Send an HTTP GET request to the URL and get the HTML content
response = requests.get(url)
html_content = response.text

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(html_content, 'lxml')

# Find the first tag in the HTML document

# Print the first tag
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of potato museums - Wikipedia</title>
# <script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],
# "wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"0e9d0f28-f4dd-49c2-b998-60c7e6dc4c83","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_potato_museums","wgTitle":"List of potato museums","wgCurRevisionId":1143803805,"wgRevisionId":1143803805,"wgArticleId":15328380,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Danish-language sources (da)","Articles with Italian-language sources (it)","Articles with short description","Short description is different from Wikidata","Potato museums","Lists of museums by subject"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_potato_museums","wgRelevantArticleId":15328380,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,
# "wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":8000,"wgULSCurrentAutonym":"English","wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q51845457","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,
# "wgGELevelingUpEnabledForUser":false};RLSTATE={"skins.vector.user.styles":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","mediawiki.page.gallery.styles":"ready","codex-search-styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.media","site","mediawiki.page.ready","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups",
# "ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});</script>
# <link href="/w/load.php?lang=en&amp;modules=codex-search-styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.page.gallery.styles%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <meta content="MediaWiki 1.41.0-wmf.29" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="max-image-preview:standard" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/PEI_Potato_Museum_-_panoramio.jpg/1200px-PEI_Potato_Museum_-_panoramio.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="900" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/PEI_Potato_Museum_-_panoramio.jpg/800px-PEI_Potato_Museum_-_panoramio.jpg" property="og:image"/>
# <meta content="800" property="og:image:width"/>
# <meta content="600" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/PEI_Potato_Museum_-_panoramio.jpg/640px-PEI_Potato_Museum_-_panoramio.jpg" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="480" property="og:image:height"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="List of potato museums - Wikipedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/List_of_potato_museums" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/w/index.php?title=List_of_potato_museums&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://en.wikipedia.org/wiki/List_of_potato_museums" rel="canonical"/>
# <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.en" rel="license"/>
# <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_potato_museums rootpage-List_of_potato_museums skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark" role="navigation">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label"><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
# <span class="vector-dropdown-label-text">Main menu</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
# <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
# <div class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned" data-feature-name="main-menu-pinned" data-pinnable-element-id="vector-main-menu" data-pinned-container-id="vector-main-menu-pinned-container" data-unpinned-container-id="vector-main-menu-unpinned-container">
# <div class="vector-pinnable-header-label">Main menu</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">hide</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
# <div class="vector-menu-heading">
# 		Navigation
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a></li><li class="mw-list-item" id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li class="mw-list-item" id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a></li><li class="mw-list-item" id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li class="mw-list-item" id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-interaction" id="p-interaction">
# <div class="vector-menu-heading">
# 		Contribute
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li class="mw-list-item" id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a></li><li class="mw-list-item" id="n-upload"><a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-main-menu-action vector-main-menu-action-lang-alert">
# <div class="vector-main-menu-action-item">
# <div class="vector-main-menu-action-heading vector-menu-heading">Languages</div>
# <div class="vector-main-menu-action-content vector-menu-content">
# <div class="mw-message-box cdx-message cdx-message--block mw-message-box-notice cdx-message--notice vector-language-sidebar-alert"><span class="cdx-message__icon"></span><div class="cdx-message__content">Language links are at the top of the page across from the title.</div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <a class="mw-logo" href="/wiki/Main_Page">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
# <span class="mw-logo-container">
# <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
# <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
# </span>
# </a>
# </div>
# <div class="vector-header-end">
# <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
# <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Special:Search" id="" title="Search Wikipedia [f]"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
# <span>Search</span>
# </a>
# <div class="vector-typeahead-search-container">
# <div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
# <form action="/w/index.php" class="cdx-search-input cdx-search-input--has-end-button" id="searchform">
# <div class="cdx-search-input__input-wrapper" data-search-loc="header-moved" id="simpleSearch">
# <div class="cdx-text-input cdx-text-input--has-start-icon">
# <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="cdx-text-input__input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
# <span class="cdx-text-input__icon cdx-text-input__start-icon"></span>
# </div>
# <input name="title" type="hidden" value="Special:Search"/>
# </div>
# <button class="cdx-button cdx-search-input__end-button">Search</button>
# </form>
# </div>
# </div>
# </div>
# <nav aria-label="Personal tools" class="vector-user-links" role="navigation">
# <div class="vector-menu mw-portlet mw-portlet-vector-user-menu-overflow" id="p-vector-user-menu-overflow">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item" id="pt-createaccount-2"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+potato+museums" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login-2"><a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+potato+museums" title="You're encouraged to log in; however, it's not mandatory. [o]"><span>Log in</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out" id="vector-user-links-dropdown" title="Log in and more options">
# <input aria-haspopup="true" aria-label="Personal tools" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-user-links-dropdown" id="vector-user-links-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-user-links-dropdown-checkbox" id="vector-user-links-dropdown-label"><span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>
# <span class="vector-dropdown-label-text">Personal tools</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="User menu">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item" id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+potato+museums" title="You are encouraged to create an account and log in; however, it is not mandatory"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Create account</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login"><a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+potato+museums" title="You're encouraged to log in; however, it's not mandatory. [o]"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Log in</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor" id="p-user-menu-anon-editor">
# <div class="vector-menu-heading">
# 		Pages for logged out editors <a aria-label="Learn more about editing" href="/wiki/Help:Introduction"><span>learn more</span></a>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="pt-anoncontribs"><a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]"><span>Contributions</span></a></li><li class="mw-list-item" id="pt-anontalk"><a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]"><span>Talk</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# </div>
# <div class="mw-page-container">
# <div class="mw-page-container-inner">
# <div class="vector-main-menu-container">
# <div id="mw-navigation">
# <nav aria-label="Site" class="vector-main-menu-landmark" id="mw-panel" role="navigation">
# <div class="vector-pinned-container" id="vector-main-menu-pinned-container">
# </div>
# </nav>
# </div>
# </div>
# <div class="vector-sitenotice-container">
# <div id="siteNotice"><!-- CentralNotice --></div>
# </div>
# <input class="vector-menu-checkbox" id="vector-toc-collapsed-checkbox" type="checkbox"/>
# <nav aria-label="Contents" class="mw-table-of-contents-container vector-toc-landmark vector-sticky-pinned-container" data-event-name="ui.sidebar-toc" id="mw-panel-toc" role="navigation">
# <div class="vector-pinned-container" id="vector-toc-pinned-container">
# <div class="vector-toc vector-pinnable-element" id="vector-toc">
# <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-feature-name="toc-pinned" data-pinnable-element-id="vector-toc">
# <h2 class="vector-pinnable-header-label">Contents</h2>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>
# </div>
# <ul class="vector-toc-contents" id="mw-panel-toc-list">
# <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
# <a class="vector-toc-link" href="#">
# <div class="vector-toc-text">(Top)</div>
# </a>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Austria">
# <a class="vector-toc-link" href="#Austria">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>Austria</div>
# </a>
# <ul class="vector-toc-list" id="toc-Austria-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Belgium">
# <a class="vector-toc-link" href="#Belgium">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2</span>Belgium</div>
# </a>
# <ul class="vector-toc-list" id="toc-Belgium-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Canada">
# <a class="vector-toc-link" href="#Canada">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3</span>Canada</div>
# </a>
# <ul class="vector-toc-list" id="toc-Canada-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Denmark">
# <a class="vector-toc-link" href="#Denmark">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4</span>Denmark</div>
# </a>
# <ul class="vector-toc-list" id="toc-Denmark-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-France">
# <a class="vector-toc-link" href="#France">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">5</span>France</div>
# </a>
# <ul class="vector-toc-list" id="toc-France-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Germany">
# <a class="vector-toc-link" href="#Germany">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6</span>Germany</div>
# </a>
# <ul class="vector-toc-list" id="toc-Germany-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Italy">
# <a class="vector-toc-link" href="#Italy">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">7</span>Italy</div>
# </a>
# <ul class="vector-toc-list" id="toc-Italy-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Lithuania">
# <a class="vector-toc-link" href="#Lithuania">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">8</span>Lithuania</div>
# </a>
# <ul class="vector-toc-list" id="toc-Lithuania-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-United_States">
# <a class="vector-toc-link" href="#United_States">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">9</span>United States</div>
# </a>
# <ul class="vector-toc-list" id="toc-United_States-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-See_also">
# <a class="vector-toc-link" href="#See_also">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">10</span>See also</div>
# </a>
# <ul class="vector-toc-list" id="toc-See_also-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-References">
# <a class="vector-toc-link" href="#References">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">11</span>References</div>
# </a>
# <ul class="vector-toc-list" id="toc-References-sublist">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="mw-content-container">
# <main class="mw-body" id="content" role="main">
# <header class="mw-body-header vector-page-titlebar">
# <label aria-controls="vector-toc" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet vector-button-flush-left cdx-button--icon-only" for="vector-toc-collapsed-checkbox" id="vector-toc-collapsed-button" role="button" tabindex="0" title="Table of Contents">
# <span class="vector-icon mw-ui-icon-wikimedia-listBullet"></span>
# <span>Toggle the table of contents</span>
# </label>
# <nav aria-label="Contents" class="vector-toc-landmark" role="navigation">
# <div class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left" id="vector-page-titlebar-toc">
# <input aria-haspopup="true" aria-label="Toggle the table of contents" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label"><span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet"></span>
# <span class="vector-dropdown-label-text">Toggle the table of contents</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-titlebar-toc-unpinned-container">
# </div>
# </div>
# </div>
# </nav>
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">List of potato museums</span></h1>
# <div class="vector-dropdown mw-portlet mw-portlet-lang" id="p-lang-btn">
# <input aria-haspopup="true" aria-label="Go to an article in another language. Available in 2 languages" class="vector-dropdown-checkbox mw-interlanguage-selector" data-event-name="ui.dropdown-p-lang-btn" id="p-lang-btn-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-2" for="p-lang-btn-checkbox" id="p-lang-btn-label"><span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive"></span>
# <span class="vector-dropdown-label-text">2 languages</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="interlanguage-link interwiki-fr mw-list-item"><a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Liste_des_mus%C3%A9es_de_la_pomme_de_terre" hreflang="fr" lang="fr" title="Liste des musées de la pomme de terre – French"><span>Français</span></a></li><li class="interlanguage-link interwiki-id mw-list-item"><a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/Daftar_museum_kentang" hreflang="id" lang="id" title="Daftar museum kentang – Indonesian"><span>Bahasa Indonesia</span></a></li>
# </ul>
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q51845457#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </div>
# </div>
# </header>
# <div class="vector-page-toolbar">
# <div class="vector-page-toolbar-container">
# <div id="left-navigation">
# <nav aria-label="Namespaces">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages" id="p-associated-pages">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-nstab-main"><a accesskey="c" href="/wiki/List_of_potato_museums" title="View the content page [c]"><span>Article</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-talk"><a accesskey="t" href="/wiki/Talk:List_of_potato_museums" rel="discussion" title="Discuss improvements to the content page [t]"><span>Talk</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-dropdown emptyPortlet" id="p-variants">
# <input aria-haspopup="true" aria-label="Change language variant" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-p-variants" id="p-variants-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="p-variants-checkbox" id="p-variants-label"><span class="vector-dropdown-label-text">English</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-variants emptyPortlet" id="p-variants">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="vector-collapsible" id="right-navigation">
# <nav aria-label="Views">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views" id="p-views">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-view"><a href="/wiki/List_of_potato_museums"><span>Read</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-edit"><a accesskey="e" href="/w/index.php?title=List_of_potato_museums&amp;action=edit" title="Edit this page [e]"><span>Edit</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-history"><a accesskey="h" href="/w/index.php?title=List_of_potato_museums&amp;action=history" title="Past revisions of this page [h]"><span>View history</span></a></li>
# </ul>
# </div>
# </div>
# </nav>
# <nav aria-label="Page tools" class="vector-page-tools-landmark">
# <div class="vector-dropdown vector-page-tools-dropdown" id="vector-page-tools-dropdown">
# <input aria-haspopup="true" aria-label="Tools" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-tools-dropdown" id="vector-page-tools-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="vector-page-tools-dropdown-checkbox" id="vector-page-tools-dropdown-label"><span class="vector-dropdown-label-text">Tools</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-tools-unpinned-container">
# <div class="vector-page-tools vector-pinnable-element" id="vector-page-tools">
# <div class="vector-pinnable-header vector-page-tools-pinnable-header vector-pinnable-header-unpinned" data-feature-name="page-tools-pinned" data-pinnable-element-id="vector-page-tools" data-pinned-container-id="vector-page-tools-pinned-container" data-unpinned-container-id="vector-page-tools-unpinned-container">
# <div class="vector-pinnable-header-label">Tools</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-page-tools.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-page-tools.unpin">hide</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items" id="p-cactions" title="More options">
# <div class="vector-menu-heading">
# 		Actions
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-more-collapsible-item mw-list-item" id="ca-more-view"><a href="/wiki/List_of_potato_museums"><span>Read</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-edit"><a accesskey="e" href="/w/index.php?title=List_of_potato_museums&amp;action=edit" title="Edit this page [e]"><span>Edit</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-history"><a href="/w/index.php?title=List_of_potato_museums&amp;action=history"><span>View history</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-tb" id="p-tb">
# <div class="vector-menu-heading">
# 		General
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_potato_museums" title="List of all English Wikipedia pages containing links to this page [j]"><span>What links here</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_potato_museums" rel="nofollow" title="Recent changes in pages linked from this page [k]"><span>Related changes</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]"><span>Upload file</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=List_of_potato_museums&amp;oldid=1143803805" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=List_of_potato_museums&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_potato_museums&amp;id=1143803805&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li class="mw-list-item" id="t-urlshortener"><a href="/w/index.php?title=Special:UrlShortener&amp;url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FList_of_potato_museums"><span>Get shortened URL</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q51845457" title="Structured data on this page hosted by Wikidata [g]"><span>Wikidata item</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-coll-print_export" id="p-coll-print_export">
# <div class="vector-menu-heading">
# 		Print/export
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=List_of_potato_museums&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=List_of_potato_museums&amp;printable=yes" title="Printable version of this page [p]"><span>Printable version</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-wikibase-otherprojects" id="p-wikibase-otherprojects">
# <div class="vector-menu-heading">
# 		In other projects
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="wb-otherproject-link wb-otherproject-commons mw-list-item"><a href="https://commons.wikimedia.org/wiki/Category:Potato_museums" hreflang="en"><span>Wikimedia Commons</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# <div class="vector-column-end">
# <nav aria-label="Page tools" class="vector-page-tools-landmark vector-sticky-pinned-container">
# <div class="vector-pinned-container" id="vector-page-tools-pinned-container">
# </div>
# </nav>
# </div>
# <div aria-labelledby="firstHeading" class="vector-body" data-mw-ve-target-container="" id="bodyContent">
# <div class="vector-body-before-content">
# <div class="mw-indicators">
# </div>
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# </div>
# <div id="contentSub"><div id="mw-content-subtitle"></div></div>
# <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><p>
# There are a number of <a href="/wiki/Museum" title="Museum">museums</a> dedicated to <a href="/wiki/Potato" title="Potato">potatoes</a> around the world, predominantly in North America and Europe.<sup class="reference" id="cite_ref-cbp2018_1-0"><a href="#cite_note-cbp2018-1">[1]</a></sup>
# </p>
# <figure class="mw-default-size mw-halign-right" typeof="mw:File/Thumb"><a class="mw-file-description" href="/wiki/File:PEI_Potato_Museum_-_panoramio.jpg"><img class="mw-file-element" data-file-height="2448" data-file-width="3264" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/PEI_Potato_Museum_-_panoramio.jpg/220px-PEI_Potato_Museum_-_panoramio.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/PEI_Potato_Museum_-_panoramio.jpg/330px-PEI_Potato_Museum_-_panoramio.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2d/PEI_Potato_Museum_-_panoramio.jpg/440px-PEI_Potato_Museum_-_panoramio.jpg 2x" width="220"/></a><figcaption>Prince Edward Island Potato Museum</figcaption></figure>
# <meta property="mw:PageProp/toc"/>
# <h2><span class="mw-headline" id="Austria">Austria</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=1" title="Edit section: Austria">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li>Waldviertler Erdäpfelwelt (Waldviertler potato world) is a museum with interactive displays located in the town hall of <a href="/wiki/Schweiggers" title="Schweiggers">Schweiggers</a> displaying the history and uses of potatoes to the present day.<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup></li></ul>
# <h2><span class="mw-headline" id="Belgium">Belgium</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=2" title="Edit section: Belgium">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><i>Musée vivant de la pomme de terre</i> ("Living Museum of the Potato") in <a href="/wiki/Genappe" title="Genappe">Genappe</a> is part of the <a href="/wiki/Wallonia" title="Wallonia">Wallonia</a> Botanical Gardens and also houses a collection of onions from northern Europe.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup></li>
# <li><i><a href="/wiki/Frietmuseum" title="Frietmuseum">Frietmuseum</a></i> in <a href="/wiki/Bruges" title="Bruges">Bruges</a> is dedicated to chips (or fries in American-English) and is located in one of Bruges' oldest buildings, dated 1399.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup></li></ul>
# <h2><span class="mw-headline" id="Canada">Canada</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=3" title="Edit section: Canada">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li>The Canadian Potato Museum in <a href="/wiki/O%27Leary,_Prince_Edward_Island" title="O'Leary, Prince Edward Island">O'Leary, Prince Edward Island</a>, claims to contain the world's largest collection of potato artifacts. It is also home to a Potato Hall of Fame. A 14-foot (4.3 m) high giant potato made of <a class="mw-redirect" href="/wiki/Fibreglass" title="Fibreglass">fibreglass</a> stands at the entrance and visitors can learn about the origins of the wild potato up to modern day agricultural practices.<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup><sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup></li>
# <li>Potato World is a museum dedicated to the potato. It is located in <a href="/wiki/Florenceville-Bristol" title="Florenceville-Bristol">Florenceville-Bristol</a>, <a href="/wiki/New_Brunswick" title="New Brunswick">New Brunswick</a>, known as the french fry capital of the world.<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup></li></ul>
# <h2><span class="mw-headline" id="Denmark">Denmark</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=4" title="Edit section: Denmark">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><i>Danmarks Kartoffelmuseum</i> ("Danish Potato Museum") in <a href="/wiki/Otterup" title="Otterup">Otterup</a><sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup> is part of the Hofmansgave estate. The Hofmansgaves were responsible for popularising the potato in Denmark where potatoes were known as "German lumps".<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup></li></ul>
# <h2><span class="mw-headline" id="France">France</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=5" title="Edit section: France">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><i>Moulin Gentrey</i> in <a href="/wiki/Harsault" title="Harsault">Harsault</a> <a class="extiw" href="https://fr.wikipedia.org/wiki/Moulin_Gentrey" title="fr:Moulin Gentrey">(fr)</a> is a former starch mill dating from 1870 which contains a small potato museum as part of a historical tour of starch making for the textile industry.<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup><sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup></li></ul>
# <h2><span class="mw-headline" id="Germany">Germany</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=6" title="Edit section: Germany">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><i>Deutsches Kartoffelmuseum</i> ("German Potato Museum") in <a href="/wiki/Fu%C3%9Fg%C3%B6nheim" title="Fußgönheim">Fußgönheim</a> <a class="extiw" href="https://de.wikipedia.org/wiki/Deutsches_Kartoffelmuseum" title="de:Deutsches Kartoffelmuseum">(de)</a> is housed in a former synagogue next to the Fußgönheim Agricultural Museum. The museum dates from 1987.<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup></li>
# <li><i><a class="mw-redirect" href="/wiki/Das_Kartoffelmuseum" title="Das Kartoffelmuseum">Das Kartoffelmuseum</a></i> ("The Potato Museum") in <a href="/wiki/Munich" title="Munich">Munich</a> dates from 1996 and is run by the Otto Eckart Foundation on behalf of Pfanni GmbH, a division of <a href="/wiki/Unilever" title="Unilever">Unilever</a>.<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup><sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup></li>
# <li><i>Vorpommersches Kartoffelmuseum</i> ("Potato Museum of <a class="mw-redirect" href="/wiki/Vorpommern" title="Vorpommern">Vorpommern</a>") in <a href="/wiki/Tribsees" title="Tribsees">Tribsees</a> <a class="extiw" href="https://de.wikipedia.org/wiki/Vorpommersches_Kartoffelmuseum" title="de:Vorpommersches Kartoffelmuseum">(de)</a><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup></li></ul>
# <h2><span class="mw-headline" id="Italy">Italy</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=7" title="Edit section: Italy">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><i>Museo della patata</i> ("Potato Museum") in <a href="/wiki/Budrio" title="Budrio">Budrio</a><sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup></li></ul>
# <h2><span class="mw-headline" id="Lithuania">Lithuania</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=8" title="Edit section: Lithuania">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li>There is a <i>Bulvės muziejus</i> ("Potato Museum") in <a href="/wiki/Kudirkos_Naumiestis" title="Kudirkos Naumiestis">Kudirkos Naumiestis</a>, near the border with Kaliningrad.</li></ul>
# <h2><span class="mw-headline" id="United_States">United States</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_potato_museums&amp;action=edit&amp;section=9" title="Edit section: United States">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><a href="/wiki/Potato_Museum" title="Potato Museum">Potato Museum</a> in <a class="mw-redirect" href="/wiki/Albuquerque" title="Albuquerque">Albuquerque</a>, <a href="/wiki/New_Mexico" title="New Mexico">New Mexico</a>, was originally housed in the basement of E. Thomas and Meredith Hughes' basement in <a href="/wiki/Washington,_D.C." title="Washington, D.C.">Washington, D.C.</a>, before moving to Albuquerque in 1993. It began in 1975 and is a <a href="/wiki/Nonprofit_organization" title="Nonprofit organization">nonprofit organization</a>.<sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup><sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[19]</a></sup></li>
# <li><a href="/wiki/Idaho_Potato_Museum" title="Idaho Potato Museum">Idaho Potato Museum</a> is in <a href="/wiki/Blackfoot,_Idaho" title="Blackfoot, Idaho">Blackfoot</a>, <a href="/wiki/Idaho" title="Idaho">Idaho</a>, and among the exhibits has the world's largest potato chip (crisp in British-English), a <a href="/wiki/Pringles" title="Pringles">Pringle</a> measuring 25 inches (64 cm)<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[20]</a></sup></li></ul>
# <style data-mw-deduplicate="TemplateStyles:r1021810730">@media all and (max-width:720px){.mw-parser-output .mod-gallery{width:100%!important}}.mw-parser-output .mod-gallery{display:table}.mw-parser-output .mod-gallery-default{background:transparent;margin-top:0.3em}.mw-parser-output .mod-gallery-center{margin-left:auto;margin-right:auto}.mw-parser-output .mod-gallery-left{float:left}.mw-parser-output .mod-gallery-right{float:right}.mw-parser-output .mod-gallery-none{float:none}.mw-parser-output .mod-gallery-collapsible{width:100%}.mw-parser-output .mod-gallery .title,.mw-parser-output .mod-gallery .main,.mw-parser-output .mod-gallery .footer{display:table-row}.mw-parser-output .mod-gallery .title>div{display:table-cell;padding:0.2em 0 0.6em 1.6em;text-align:center;font-weight:bold}.mw-parser-output .mod-gallery .main>div{display:table-cell}.mw-parser-output .mod-gallery .gallery{line-height:1.35em}.mw-parser-output .mod-gallery .footer>div{display:table-cell;padding:0.2em 0 0.6em 1.6em;text-align:right;font-size:80%;line-height:1em}.mw-parser-output .mod-gallery .title>div *,.mw-parser-output .mod-gallery .footer>div *{overflow:visible}.mw-parser-output .mod-gallery .gallerybox img{background:none!important}.mw-parser-output .mod-gallery .bordered-images .thumb img{border:solid #eaecf0 1px}.mw-parser-output .mod-gallery .whitebg .thumb{background:#fff!important}</style><div class="mod-gallery mod-gallery-default mod-gallery-center"><div class="main"><div><ul class="gallery mw-gallery-traditional nochecker bordered-images whitebg">
# <li class="gallerybox" style="width: 195px">
# <div class="thumb" style="width: 190px; height: 200px;"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:IdahoPotatoMuseumPotato.jpg" title="Idaho Potato Museum"><img alt="Idaho Potato Museum" class="mw-file-element" data-file-height="3000" data-file-width="4000" decoding="async" height="120" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4a/IdahoPotatoMuseumPotato.jpg/160px-IdahoPotatoMuseumPotato.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4a/IdahoPotatoMuseumPotato.jpg/240px-IdahoPotatoMuseumPotato.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4a/IdahoPotatoMuseumPotato.jpg/320px-IdahoPotatoMuseumPotato.jpg 2x" width="160"/></a></span></div>
# <div class="gallerytext">
# <p>Idaho Potato Museum
# </p>
# </div>
# </li>
# ...
# </li>
# <li id="cite_note-12"><span class="mw-cite-backlink"><b><a href="#cite_ref-12">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://www.moulingentrey.fr/5.html" rel="nofollow">"Féculerie"</a>. <i>Moulin Gentry</i><span class="reference-accessdate">. Retrieved <span class="nowrap">16 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Moulin+Gentry&amp;rft.atitle=F%C3%A9culerie&amp;rft_id=http%3A%2F%2Fwww.moulingentrey.fr%2F5.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# <li id="cite_note-13"><span class="mw-cite-backlink"><b><a href="#cite_ref-13">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://www.deutscheskartoffelmuseum.de/das-museum/geschichte-des-museums" rel="nofollow">"Geschichte des Museums"</a>. <i>Deutsches Kartoffelmuseum</i><span class="reference-accessdate">. Retrieved <span class="nowrap">16 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Deutsches+Kartoffelmuseum&amp;rft.atitle=Geschichte+des+Museums&amp;rft_id=http%3A%2F%2Fwww.deutscheskartoffelmuseum.de%2Fdas-museum%2Fgeschichte-des-museums&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# <li id="cite_note-14"><span class="mw-cite-backlink"><b><a href="#cite_ref-14">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://www.sueddeutsche.de/muenchen/berg-am-laim-kartoffelmuseum-zieht-ins-werksviertel-1.2908933" rel="nofollow">"Kartoffelmuseum zieht ins Werksviertel"</a>. <i>Süddeutsche Zeitung</i><span class="reference-accessdate">. Retrieved <span class="nowrap">16 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=S%C3%BCddeutsche+Zeitung&amp;rft.atitle=Kartoffelmuseum+zieht+ins+Werksviertel&amp;rft_id=http%3A%2F%2Fwww.sueddeutsche.de%2Fmuenchen%2Fberg-am-laim-kartoffelmuseum-zieht-ins-werksviertel-1.2908933&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# <li id="cite_note-15"><span class="mw-cite-backlink"><b><a href="#cite_ref-15">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://www.kartoffelmuseum.de/museumseite.html" rel="nofollow">"Homepage"</a>. <i>Kartoffelmuseum</i><span class="reference-accessdate">. Retrieved <span class="nowrap">16 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Kartoffelmuseum&amp;rft.atitle=Homepage&amp;rft_id=http%3A%2F%2Fwww.kartoffelmuseum.de%2Fmuseumseite.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# <li id="cite_note-16"><span class="mw-cite-backlink"><b><a href="#cite_ref-16">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="http://kartoffelmuseum.stadt-tribsees.de" rel="nofollow">"Uber Uns"</a>. <i>Vorpommersches Kartoffelmuseum</i><span class="reference-accessdate">. Retrieved <span class="nowrap">17 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Vorpommersches+Kartoffelmuseum&amp;rft.atitle=Uber+Uns&amp;rft_id=http%3A%2F%2Fkartoffelmuseum.stadt-tribsees.de&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# <li id="cite_note-17"><span class="mw-cite-backlink"><b><a href="#cite_ref-17">^</a></b></span> <span class="reference-text"><a class="external text" href="http://www.orizzontidipianura.it/interno.php?ID_MENU=194&amp;ID_PAGE=2224" rel="nofollow">Museo della patata</a>, Orizzonti di pianura <span class="languageicon">(in Italian)</span></span>
# </li>
# <li id="cite_note-18"><span class="mw-cite-backlink"><b><a href="#cite_ref-18">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1" id="CITEREFRichman">Richman, Ruth M. <a class="external text" href="https://www.nytimes.com/1989/11/22/garden/potato-museum-seeks-a-new-home.html" rel="nofollow">"Potato Museum Seeks a New Home"</a>. <i>New York Times</i><span class="reference-accessdate">. Retrieved <span class="nowrap">17 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=New+York+Times&amp;rft.atitle=Potato+Museum+Seeks+a+New+Home&amp;rft.aulast=Richman&amp;rft.aufirst=Ruth+M.&amp;rft_id=https%3A%2F%2Fwww.nytimes.com%2F1989%2F11%2F22%2Fgarden%2Fpotato-museum-seeks-a-new-home.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# <li id="cite_note-19"><span class="mw-cite-backlink"><b><a href="#cite_ref-19">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.centerfornonprofitexcellence.org/nonprofit-directory/nonprofit/13547" rel="nofollow">"The Potato Museum"</a>. <i>Center for non-profit excellence</i><span class="reference-accessdate">. Retrieved <span class="nowrap">17 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Center+for+non-profit+excellence&amp;rft.atitle=The+Potato+Museum&amp;rft_id=https%3A%2F%2Fwww.centerfornonprofitexcellence.org%2Fnonprofit-directory%2Fnonprofit%2F13547&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# <li id="cite_note-20"><span class="mw-cite-backlink"><b><a href="#cite_ref-20">^</a></b></span> <span class="reference-text"><link href="mw-data:TemplateStyles:r1133582631" rel="mw-deduplicated-inline-style"/><cite class="citation web cs1"><a class="external text" href="https://www.yellowstonepark.com/things-to-do/idaho-potato-museum" rel="nofollow">"Idaho Potato Museum Southwest of Yellowstone"</a>. <i>Yellowstone Park</i><span class="reference-accessdate">. Retrieved <span class="nowrap">17 January</span> 2018</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Yellowstone+Park&amp;rft.atitle=Idaho+Potato+Museum+Southwest+of+Yellowstone&amp;rft_id=https%3A%2F%2Fwww.yellowstonepark.com%2Fthings-to-do%2Fidaho-potato-museum&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AList+of+potato+museums"></span></span>
# </li>
# </ol></div></div>
# <!--
# NewPP limit report
# Parsed by mw1368
# Cached time: 20231009151510
# Cache expiry: 1814400
# Reduced expiry: false
# Complications: [vary‐revision‐sha1, show‐toc]
# CPU time usage: 0.366 seconds
# Real time usage: 0.460 seconds
# Preprocessor visited node count: 1049/1000000
# Post‐expand include size: 29590/2097152 bytes
# Template argument size: 272/2097152 bytes
# Highest expansion depth: 9/100
# Expensive parser function count: 2/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 59137/5000000 bytes
# Lua time usage: 0.269/10.000 seconds
# Lua memory usage: 16417788/52428800 bytes
# Number of Wikibase entities loaded: 0/400
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  423.123      1 -total
#  62.47%  264.331      1 Template:Reflist
#  25.18%  106.531      1 Template:In_lang
#  16.71%   70.701     18 Template:Cite_web
#  15.87%   67.148      1 Template:Short_description
#  15.33%   64.874      1 Template:Cite_book
#   8.75%   37.023      1 Template:Gallery
#   7.12%   30.139      2 Template:Pagetype
#   6.33%   26.790      2 Template:Convert
#   5.43%   22.993      3 Template:Main_other
# -->
# <!-- Saved in parser cache with key enwiki:pcache:idhash:15328380-0!canonical and timestamp 20231009151510 and revision id 1143803805. Rendering was triggered because: page-view
#  -->
# </div><!--esi <esi:include src="/esitest-fa8a495983347898/content" /> --><noscript><img alt="" height="1" src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" title="" width="1"/></noscript>
# <div class="printfooter" data-nosnippet="">Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=List_of_potato_museums&amp;oldid=1143803805">https://en.wikipedia.org/w/index.php?title=List_of_potato_museums&amp;oldid=1143803805</a>"</div></div>
# <div class="catlinks" data-mw="interface" id="catlinks"><div class="mw-normal-catlinks" id="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Potato_museums" title="Category:Potato museums">Potato museums</a></li><li><a href="/wiki/Category:Lists_of_museums_by_subject" title="Category:Lists of museums by subject">Lists of museums by subject</a></li></ul></div><div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">Hidden categories: <ul><li><a href="/wiki/Category:CS1_Danish-language_sources_(da)" title="Category:CS1 Danish-language sources (da)">CS1 Danish-language sources (da)</a></li><li><a href="/wiki/Category:Articles_with_Italian-language_sources_(it)" title="Category:Articles with Italian-language sources (it)">Articles with Italian-language sources (it)</a></li><li><a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">Articles with short description</a></li><li><a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">Short description is different from Wikidata</a></li></ul></div></div>
# </div>
# </main>
# </div>
# <div class="mw-footer-container">
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 10 March 2023, at 00:29<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license">Creative Commons Attribution-ShareAlike License 4.0</a><a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-wm-codeofconduct"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Universal_Code_of_Conduct">Code of Conduct</a></li>
# <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">Cookie statement</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_potato_museums&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# </div>
# </div>
# </div>
# <div class="vector-settings" id="p-dock-bottom">
# <ul>
# <li>
# <button class="cdx-button cdx-button--icon-only vector-limited-width-toggle" id=""><span class="vector-icon mw-ui-icon-fullScreen mw-ui-icon-wikimedia-fullScreen"></span>
# <span>Toggle limited content width</span>
# </button>
# </li>
# </ul>
# </div>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw1389","wgBackendResponseTime":143,"wgPageParseReport":{"limitreport":{"cputime":"0.366","walltime":"0.460","ppvisitednodes":{"value":1049,"limit":1000000},"postexpandincludesize":{"value":29590,"limit":2097152},"templateargumentsize":{"value":272,"limit":2097152},"expansiondepth":{"value":9,"limit":100},"expensivefunctioncount":{"value":2,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":59137,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  423.123      1 -total"," 62.47%  264.331      1 Template:Reflist"," 25.18%  106.531      1 Template:In_lang"," 16.71%   70.701     18 Template:Cite_web"," 15.87%   67.148      1 Template:Short_description"," 15.33%   64.874      1 Template:Cite_book","  8.75%   37.023      1 Template:Gallery","  7.12%   30.139      2 Template:Pagetype","  6.33%   26.790      2 Template:Convert","  5.43%   22.993      3 Template:Main_other"]},"scribunto":{"limitreport-timeusage":{"value":"0.269","limit":"10.000"},"limitreport-memusage":{"value":16417788,"limit":52428800}},"cachereport":{"origin":"mw1368","timestamp":"20231009151510","ttl":1814400,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"List of potato museums","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_potato_museums","sameAs":"http:\/\/www.wikidata.org\/entity\/Q51845457","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q51845457","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2008-01-20T15:16:58Z","dateModified":"2023-03-10T00:29:46Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/2\/2d\/PEI_Potato_Museum_-_panoramio.jpg","headline":"Wikimedia list article"}</script>
# </body>
# </html>

# %%
count = str(soup).count("<a")
count
# Out:
# 201

# %%
len(soup.find_all("a"))
# Out:
# 201

# %%
df = pd.DataFrame({
    "Article_Name": [],
    "Article_Image_Count": []
})

# %%
for i in range(1000):
    url = "https://en.wikipedia.org/wiki/Special:Random"
    response = requests.get(url)
    html_content = response.text
    soup = BeautifulSoup(html_content, 'lxml')
    image_tags = soup.find_all('img')

    image_tags = soup.find_all('img')
    
    image_count = 0
    
    for img in image_tags:
        width = int(img.get('width', 0))
        height = int(img.get('height', 0))

        if width > 50 and height > 50:
            image_count+=1

    
    article_title_tag = soup.find('h1')
    article_name = "(name not found)"
    if article_title_tag:
        article_name = article_title_tag.text.strip()
        
    print(f'The article {article_name} contains {image_count} images.')
    df.loc[i, "Article_Name"] = article_name
    df.loc[i, "Article_Image_Count"] = image_count
# Out:
# The article Goldasht, Lamerd contains 1 images.
# The article The Rabbits' Wedding contains 1 images.
# The article Ballot Monkeys contains 0 images.
# The article Tepuihyla shushupe contains 1 images.
# The article Resni.ca contains 0 images.
# The article Samhah contains 2 images.
# The article Alton Abbey contains 1 images.
# The article Gymnogeophagus tiraparae contains 2 images.
# The article Karges Furniture contains 0 images.
# The article Tennis (paper game) contains 2 images.
# The article Nando (futsal player) contains 0 images.
# The article Newton County Jail contains 3 images.
# The article Abdullah bin Isa Al Khalifa contains 0 images.
# The article Sink or Swim (1990 film) contains 0 images.
# The article List of Alicante citizens contains 0 images.
# The article Nivelles-Baulers contains 2 images.
# The article Trinity's Child contains 1 images.
# The article List of 2020 Women's March locations (October) contains 0 images.
# The article Richard Jupp contains 1 images.
# The article Jewish adjacent contains 0 images.
# The article Ibigawa contains 5 images.
# The article Between Friends (1973 film) contains 0 images.
# The article Wayne Township, Marion County, Indiana contains 2 images.
# The article Kumrabaria Union contains 1 images.
# The article Silk Road Race contains 1 images.
# The article FC Zorkiy Krasnogorsk contains 1 images.
# The article Pink Anderson contains 2 images.
# The article Gmina Branice contains 1 images.
# The article Song 2 contains 1 images.
# The article Solar eclipse of February 26, 2017 contains 90 images.
# The article Apistoloricaria listrorhinos contains 0 images.
# The article John Kelly (Royal Navy officer) contains 4 images.
# The article Maija Lång contains 0 images.
# The article Qristina Ribohn contains 0 images.
# The article Fatou Jaw-Manneh contains 0 images.
# The article Euphaedra disjuncta contains 0 images.
# The article M79 grenade launcher contains 9 images.
# The article Irina Gorbacheva contains 1 images.
# The article Franz Abbé contains 0 images.
# The article Antonio da Fabriano contains 1 images.
# The article Happening '68 contains 0 images.
# The article Ballon, Charente-Maritime contains 6 images.
# The article PySCF contains 0 images.
# The article Pseudo-finite field contains 0 images.
# The article Declan Frith contains 0 images.
# The article Tervola contains 3 images.
# The article Polvadera Group contains 10 images.
# The article Abraeomorphus contains 0 images.
# The article Yekkeh Tut-e Pain contains 1 images.
# The article Small nucleolar RNA Z178 contains 1 images.
# The article T. J. Slaughter contains 0 images.
# The article Lycium australe contains 1 images.
# The article Action stroke dance notation contains 0 images.
# The article Acanthoscelides alboscutellatus contains 0 images.
# The article Dawut Abdurehim contains 0 images.
# The article USS Mitchell contains 3 images.
# The article Randall T. Eng contains 0 images.
# The article Joseph Van De Meulebroeck contains 2 images.
# The article List of University of Maryland Francis King Carey School of Law alumni contains 0 images.
# The article Sodium tetrasulfide contains 2 images.
# The article Intrepid (1829 ship) contains 0 images.
# The article Dogsomyn Ganbold contains 0 images.
# The article 2018 Fuzion 100 Surbiton Trophy contains 0 images.
# The article Boycott (2021 film) contains 2 images.
# The article Tecolotlán contains 5 images.
# The article Geneviève Simard contains 1 images.
# The article Heinrich Bernhard Oppenheim contains 0 images.
# The article Lumde contains 1 images.
# The article State Theatre (Benton Harbor, Michigan) contains 1 images.
# The article Bedik language contains 0 images.
# The article Brent Sancho contains 1 images.
# The article Egyptian Petroleum Research Institute contains 1 images.
# The article Mahito Yokota contains 0 images.
# The article Corbu, Dondușeni contains 1 images.
# The article 2017 Aegon Southsea Trophy contains 0 images.
# The article Carina Baltrip-Reyes contains 0 images.
# The article Ezira contains 0 images.
# The article Lanzhou beef noodle soup contains 6 images.
# The article Leuconitocris microphthalma contains 0 images.
# The article John Wilkinson Taylor (politician) contains 0 images.
# The article Rhonda Copelon contains 0 images.
# The article Joy Smithers contains 0 images.
# The article 1221 contains 1 images.
# The article Nancy Bonini contains 2 images.
# The article Suzhou Lakeside New City contains 0 images.
# The article Whole World Is Watching contains 1 images.
# The article Granada, Minnesota contains 2 images.
# The article Eddie Taylor contains 0 images.
# The article The Leopard (1963 film) contains 5 images.
# The article Bartolomeo Olivieri contains 0 images.
# The article Martin Tritschler contains 2 images.
# The article Virginia Ryan contains 0 images.
# The article Biturix venosata contains 0 images.
# The article Hardy Brown contains 0 images.
# The article Gori (actress) contains 0 images.
# The article 1928 Chatham Cup contains 0 images.
# The article Lauren Barnette contains 0 images.
# The article James Seehafer contains 1 images.
# The article Donald D. Chamberlin contains 1 images.
# The article The Slingshot (film) contains 0 images.
# The article Astrakhan Airlines contains 1 images.
# The article Leptojulis cyanopleura contains 2 images.
# The article A Buncha Girls contains 1 images.
# The article Aéroports du Mali contains 0 images.
# The article President Ho Chi Minh's Testament contains 4 images.
# The article Stenoma hyalocryptis contains 0 images.
# The article Dasaki Stadium contains 2 images.
# The article HMS Odiham (M2783) contains 0 images.
# The article Glen Ridge rape contains 1 images.
# The article Sushil Bhattacharya contains 0 images.
# The article 2022–23 Xavier Musketeers men's basketball team contains 1 images.
# The article Electronic monitoring in the United States contains 7 images.
# The article W. E. Mauger House contains 3 images.
# The article Akshay Kodoth contains 0 images.
# The article Mike Harcourt contains 2 images.
# The article Piaseczno contains 8 images.
# The article USCS Baltimore contains 0 images.
# The article List of people with post-traumatic stress disorder contains 10 images.
# The article 1971 Uruguayan general election contains 3 images.
# The article Boevange contains 1 images.
# The article Beresford Stakes contains 109 images.
# The article Henry Goldsmith contains 0 images.
# The article Koubéogo, Ganzourgou contains 1 images.
# The article Diggy Liggy Lo contains 0 images.
# The article Panama–Peru relations contains 4 images.
# The article Kedar Gurung contains 0 images.
# The article Cyclothiazomycin contains 3 images.
# The article Studio FOW contains 0 images.
# The article WEEP (Minnesota) contains 0 images.
# The article TUBE1 contains 4 images.
# The article Salar de Arizaro contains 7 images.
# The article Squad 85 contains 1 images.
# The article Gavin Massey contains 4 images.
# The article Current Cancer Drug Targets contains 0 images.
# The article Annabelle Terhune contains 1 images.
# The article Mahurangi Island (Goat Island) contains 1 images.
# The article Neal Bledsoe contains 0 images.
# The article Euphoria Tour (Enrique Iglesias) contains 1 images.
# The article Solly Granatstein contains 2 images.
# The article 1927 Melbourne Carnival contains 2 images.
# The article Boxing at the 1972 Summer Olympics – Light flyweight contains 0 images.
# The article O'Landa Draper contains 0 images.
# The article Yikatong contains 1 images.
# The article Liu Woying contains 1 images.
# The article All Star Racing 2 contains 1 images.
# The article Operation 7 contains 0 images.
# The article Addressable heap contains 0 images.
# The article 2020 Utah gubernatorial election contains 6 images.
# The article Paraun contains 1 images.
# The article Tashkan-e Sadat contains 1 images.
# The article Annesley Old Church contains 1 images.
# The article Anastasia Golovashkina contains 2 images.
# The article Muhammed Çalhanoğlu contains 0 images.
# The article On Saudi Arabia contains 1 images.
# The article Slim Shoulders contains 1 images.
# The article 1950 Idaho Vandals football team contains 0 images.
# The article Les Yewdale contains 0 images.
# The article Revenge eviction contains 0 images.
# The article Jo Patterson contains 0 images.
# The article It's Gonna Work Out Fine contains 1 images.
# The article Deli Yürek: Bumerang Cehennemi contains 1 images.
# The article Table tennis at the 2018 Commonwealth Games – Women's singles contains 0 images.
# The article Alexander Stoffel contains 0 images.
# The article European route E16 contains 17 images.
# The article Jovsa contains 5 images.
# The article Tom Miller (footballer, born 1990) contains 1 images.
# The article Château de Saint-Thamar contains 0 images.
# The article QuickTime File Format contains 0 images.
# The article Jones Road Distillery contains 9 images.
# The article SNUB contains 1 images.
# The article Waterford Unified School District contains 1 images.
# The article Divriği Great Mosque and Hospital contains 35 images.
# The article Demonization contains 0 images.
# The article Uenanthracus contains 0 images.
# The article 1979–80 Macedonian Republic League contains 0 images.
# The article 2018 New Mexico State Aggies football team contains 1 images.
# The article National Register of Historic Places listings in Bristol, Rhode Island contains 14 images.
# The article Turco-Persian wars contains 0 images.
# The article 1901 Rhode Island Rams football team contains 0 images.
# The article Judy Fudge contains 0 images.
# The article Natolin, Sokołów County contains 1 images.
# The article Andrei Vasyanovich contains 1 images.
# The article Tyrone Corbin contains 1 images.
# The article Félix Houphouët-Boigny contains 13 images.
# The article GPR150 contains 4 images.
# The article Drwęca Warmińska contains 1 images.
# The article Siege of Deventer (1456) contains 1 images.
# The article Herron (name) contains 0 images.
# The article Sir Brook Bridges, 1st Baronet contains 0 images.
# The article Hangin' Tough (song) contains 1 images.
# The article Dobrinka Mincheva contains 0 images.
# The article Ada Jones contains 2 images.
# The article Raisa Karmazina contains 1 images.
# The article Akeem Scott contains 1 images.
# The article Maine State Route 46 contains 2 images.
# The article 2006 Mojo Awards contains 0 images.
# The article International Alliance of Women contains 7 images.
# The article Lê Thị Phương contains 0 images.
# The article Inga neblinensis contains 1 images.
# The article Walter von Boltenstern contains 1 images.
# The article Currie Hall contains 19 images.
# The article 2011–12 Premiership Rugby contains 1 images.
# The article Association of University Staff of New Zealand contains 1 images.
# The article Vernon, Utah contains 4 images.
# The article Judge Advocate General (Australia) contains 0 images.
# The article Thomassetia contains 0 images.
# The article Andrea Lombardo contains 0 images.
# The article Moldova at the 2018 European Athletics Championships contains 1 images.
# The article Adel Al Mulla contains 0 images.
# The article A. Hamilton Thompson contains 0 images.
# The article Eric Wertheim contains 0 images.
# The article Sheephead Mountains contains 2 images.
# The article Glenside Hospital (Adelaide) contains 2 images.
# The article Fisnik Zuka contains 0 images.
# The article OK Ravinen contains 0 images.
# The article Autonomist Association contains 0 images.
# The article 1989–90 Kansas State Wildcats men's basketball team contains 0 images.
# The article 2021 Quincentennial Commemorations in the Philippines contains 2 images.
# The article Olkaria IV Geothermal Power Station contains 1 images.
# The article Sochi Thermal Power Plant contains 1 images.
# The article Pyhimys contains 1 images.
# The article Kosmic Kart contains 1 images.
# The article Isabella I of Castile contains 24 images.
# The article Jacksonville, Illinois, micropolitan area contains 1 images.
# The article Dan Hörning contains 0 images.
# The article Knut Stjerna contains 1 images.
# The article E. C. Turner contains 0 images.
# The article Katiola contains 2 images.
# The article Mount Hercules contains 0 images.
# The article Personal boundaries contains 0 images.
# The article Punto Fijo contains 4 images.
# The article Punta Carnero, Ecuador contains 2 images.
# The article SSD Women Hellas Verona contains 0 images.
# The article Indian pink contains 0 images.
# The article Umbrella (company) contains 1 images.
# The article Baritius affinis contains 0 images.
# The article Hanna Gabriels contains 1 images.
# The article Goldy Brar contains 0 images.
# The article Felix A. Reeve contains 1 images.
# The article Edward Douglas White Catholic High School contains 2 images.
# The article RAF Jurby Head contains 3 images.
# The article Sebe-Brikolo (department) contains 2 images.
# The article Camp Township, Renville County, Minnesota contains 1 images.
# The article Daniel Shirley contains 0 images.
# The article Adamit contains 4 images.
# The article Behavior tree (artificial intelligence, robotics and control) contains 3 images.
# The article Alexander Tikhmenev contains 1 images.
# The article God and eternity contains 1 images.
# The article Khishig-Öndör contains 0 images.
# The article Rudy Camacho contains 0 images.
# The article Laredo (Chris Cagle song) contains 1 images.
# The article Hangin' Tough contains 1 images.
# The article Hiawatha (riverboat) contains 1 images.
# The article André Fomitschow contains 1 images.
# The article Virginia State Route 779 contains 1 images.
# The article Australiteuthis contains 2 images.
# The article List of colleges and universities in Brahmanbaria contains 2 images.
# The article 713th Infantry Division contains 0 images.
# The article Pietro Spagnoli contains 0 images.
# The article Gold Jam Records contains 0 images.
# The article Carbocisteine contains 2 images.
# The article Ormosia romanovichiana contains 0 images.
# The article Macasinia vilhena contains 0 images.
# The article Grace and St. Peter's Church contains 3 images.
# The article 1954 Southern Conference men's basketball tournament contains 0 images.
# The article Maria Lassnig contains 6 images.
# The article Sara Craven contains 0 images.
# The article Fresno de Torote contains 3 images.
# The article Feeria contains 0 images.
# The article Frances Hughes contains 0 images.
# The article 6'''-Hydroxyneomycin C oxidase contains 0 images.
# The article Hypothetical (TV series) contains 2 images.
# The article Broströmmen contains 0 images.
# The article Totem (Zazie album) contains 1 images.
# The article Desert pride contains 0 images.
# The article Southeastern Collegiate Rugby Conference contains 2 images.
# The article Ancylis discigerana contains 5 images.
# The article Littorinimorpha contains 30 images.
# The article Day of Ukrainian Literature and Language contains 0 images.
# The article O‘rinbek Yoqubov contains 0 images.
# The article Bakerville, Tennessee contains 3 images.
# The article Malvarosa (film) contains 1 images.
# The article Ibis Dam contains 1 images.
# The article Ministry of Natural Resources of the People's Republic of China contains 1 images.
# The article Waterford, Indiana contains 2 images.
# The article Melodies of Vera Quarter contains 1 images.
# The article Powell Gardens contains 3 images.
# The article Mati Mark contains 0 images.
# The article Perfect fluid contains 1 images.
# The article 9th Light Infantry Regiment contains 3 images.
# The article Akuma no Memumemu-chan contains 1 images.
# The article Hadith Qudse contains 2 images.
# The article 1966–67 Albanian National Championship contains 0 images.
# The article Aquaculture (journal) contains 0 images.
# The article Ballylanders contains 3 images.
# The article Transport in Leeds contains 10 images.
# The article Beth Wessel-Kroeschell contains 1 images.
# The article Ham Lin̄i contains 1 images.
# The article Marwan Kenzari contains 1 images.
# The article César Herrera (rower) contains 0 images.
# The article GoldenSource contains 1 images.
# The article BB5 (film) contains 1 images.
# The article Victory Engineering contains 1 images.
# The article Israeli folk dance contains 5 images.
# The article Sex and Death 101 contains 1 images.
# The article Catch 22 (Hypocrisy album) contains 2 images.
# The article Crutched Friars contains 1 images.
# The article Härslöv Church contains 3 images.
# The article Wuluwati Dam contains 1 images.
# The article Hrag Vartanian contains 0 images.
# The article Battle of Blain contains 0 images.
# The article Maureen Hicks contains 0 images.
# The article Nadey Hakim contains 5 images.
# The article Olaug Abrahamsen contains 0 images.
# The article Marilyn Deegan contains 0 images.
# The article Peyton Place (novel) contains 1 images.
# The article Andriy Tsukanov contains 0 images.
# The article Andrew Barclay (mathematician) contains 1 images.
# The article Congress Street (Boston) contains 14 images.
# The article Buddy Baumann (baseball) contains 1 images.
# The article Hermann Rieck contains 6 images.
# The article Parks-Bentley House contains 3 images.
# The article Gun Island contains 1 images.
# The article La fuga (1937 film) contains 1 images.
# The article Breitenberg, Lower Bavaria contains 5 images.
# The article La Quarte contains 4 images.
# The article Sandy Creek (village), New York contains 2 images.
# The article Valley of the Head Hunters contains 0 images.
# The article The Message (Prison Break) contains 0 images.
# The article Oes contains 2 images.
# The article Bank Block contains 3 images.
# The article Andrew Sega contains 2 images.
# The article Santo Domingo (song) contains 1 images.
# The article Gyracanthidae contains 1 images.
# The article Gmina Łagiewniki contains 2 images.
# The article Martin Atkinson contains 2 images.
# The article Laura Moser contains 2 images.
# The article Sonja Castelein contains 0 images.
# The article Pandemis piceocola contains 0 images.
# The article Ainsworth Psalter contains 0 images.
# The article Dwayne Gratz contains 1 images.
# The article Sistema de Informações da República Portuguesa contains 2 images.
# The article Airport privacy contains 2 images.
# The article Goniobranchus tinctorius contains 0 images.
# The article Road Gang contains 1 images.
# The article Fencing at the 2015 Pan American Games contains 3 images.
# The article Willians Santana contains 0 images.
# The article Second Siddaramaiah ministry contains 23 images.
# The article Appliance classes contains 3 images.
# The article Phuket Beer contains 1 images.
# The article Parents Action League contains 0 images.
# The article Branch Building contains 4 images.
# The article Carlos Zambrano contains 5 images.
# The article Keith Simpson (footballer) contains 0 images.
# The article Trey Nielsen contains 1 images.
# The article Rhysoconcha atanuiensis contains 1 images.
# The article 2024 United States House of Representatives elections in North Carolina contains 1 images.
# The article Pitstop (video game) contains 3 images.
# The article Pinar Yolaçan contains 0 images.
# The article WNSL contains 1 images.
# The article Farnham (surname) contains 0 images.
# The article Lexington Airport (Oregon) contains 1 images.
# The article The Photograph (2020 film) contains 1 images.
# The article Oxathiane contains 0 images.
# The article MV Aegean Odyssey contains 2 images.
# The article Pedro Horrillo contains 1 images.
# The article Senate of Barbados contains 4 images.
# The article Gmina Jeżów Sudecki contains 1 images.
# The article Batibat contains 0 images.
# The article Sons of Mogh contains 1 images.
# The article Embassy of Bangladesh, Washington, D.C. contains 3 images.
# The article Betty Gordon contains 0 images.
# The article Anna Hashimoto contains 0 images.
# The article Cleone (play) contains 1 images.
# The article Burlington Refrigerator Express contains 0 images.
# The article The Middle East Journal contains 1 images.
# The article Francis Ayscough contains 2 images.
# The article Pirionimyia contains 0 images.
# The article USS Alpha (1864) contains 0 images.
# The article Borki, Gmina Jadów contains 1 images.
# The article Persicaria tinctoria contains 2 images.
# The article LCD Soundsystem contains 8 images.
# The article Diego de la Calzada contains 0 images.
# The article Offshoring Research Network contains 0 images.
# The article Boguszki, Łomża County contains 1 images.
# The article WRLO-FM contains 1 images.
# The article Elizabeth Tinnon contains 0 images.
# The article Denis Trček contains 0 images.
# The article Vietnam Populist Party contains 2 images.
# The article Athletics at the 2014 Asian Games – Women's 800 metres contains 0 images.
# The article Tropidodipsas papavericola contains 0 images.
# The article Mark Ondayko contains 0 images.
# The article Antoine-Marie Coupart contains 0 images.
# The article Aachen thermal springs contains 11 images.
# The article 2018–19 Diósgyőri VTK season contains 0 images.
# The article 1961–62 Hibernian F.C. season contains 0 images.
# The article Leonard Montague Harris contains 0 images.
# The article Eumachia frutescens contains 1 images.
# The article Andrei Vorobyov contains 0 images.
# The article Tongju Yang clan contains 0 images.
# The article IC 405 contains 4 images.
# The article Velar ejective fricative contains 0 images.
# The article Rocío Ríos contains 0 images.
# The article Trzęsów, Lower Silesian Voivodeship contains 2 images.
# The article Stanley J. Seeger contains 0 images.
# The article Sahavasa contains 1 images.
# The article Anxiotropic contains 0 images.
# The article Gioacchino Cocchi contains 1 images.
# The article Death Row Records discography contains 0 images.
# The article California State Route 271 contains 3 images.
# The article A Woman with Power of Attorney contains 1 images.
# The article Large panel system-building contains 6 images.
# The article Samuel Loomis (businessman) contains 0 images.
# The article Latin Grammy Award for Best Classical Contemporary Composition contains 0 images.
# The article Boleite contains 2 images.
# The article Socialist Labor Party (Australia) contains 0 images.
# The article École secondaire l'Horizon contains 1 images.
# The article Joanne Siegel contains 3 images.
# The article List of fried chicken dishes contains 7 images.
# The article Ronald Burroughs contains 0 images.
# The article West Kesteven Rural District contains 0 images.
# The article List of Cultural Properties of the Philippines in Bulakan, Bulacan contains 31 images.
# The article Sunny Isles Beach, Florida contains 9 images.
# The article Nobel family contains 2 images.
# The article 2008 Zimbabwean general election contains 7 images.
# The article 1970 in Soviet football contains 0 images.
# The article The Sandman: The Kindly Ones contains 1 images.
# The article 1973 All-Southwest Conference football team contains 0 images.
# The article Micah P. Hinson contains 1 images.
# The article Alan Cox (actor) contains 0 images.
# The article Lakshmi Narasimha Entertainments contains 0 images.
# The article Segaki contains 0 images.
# The article Charlotte Sting contains 2 images.
# The article AdaCamp contains 2 images.
# The article Georgia State Route 251 contains 2 images.
# The article 1905–06 Sheffield Shield season contains 0 images.
# The article Vegard Arnhoff contains 0 images.
# The article Two Thrones contains 1 images.
# The article Monkey Hips and Rice: The "5" Royales Anthology contains 1 images.
# The article Grzegorz Kielsa contains 0 images.
# The article Hugo Castejón contains 0 images.
# The article Sihala ceylonicus contains 0 images.
# The article Andy Hertzfeld contains 1 images.
# The article Chase Mishkin contains 0 images.
# The article Volantis contains 0 images.
# The article Conversation Piece at the Royal Lodge, Windsor contains 1 images.
# The article List of high commissioners of Australia to Cyprus contains 2 images.
# The article Antonie Iorgovan contains 0 images.
# The article Sergio Miguel contains 0 images.
# The article 2017 Iraq FA Cup final contains 0 images.
# The article Principal Secretary to Chief Minister contains 0 images.
# The article Bella Jimenez contains 2 images.
# The article Coregonus lavaretus contains 3 images.
# The article Cycling at the 2012 Summer Paralympics – Men's individual pursuit C5 contains 0 images.
# The article Natalie Panek contains 1 images.
# The article Roger Sherman contains 7 images.
# The article North Region Junior Football League contains 0 images.
# The article Center Strafford, New Hampshire contains 4 images.
# The article Ceramide-activated protein phosphatase contains 0 images.
# The article Calytrix viscida contains 1 images.
# The article 2017 World Open (snooker) contains 0 images.
# The article Amjad Ismail contains 0 images.
# The article Cherokee Falls contains 2 images.
# The article Griffin House (Portland, Maine) contains 3 images.
# The article Connector (mathematics) contains 0 images.
# The article Avvakumov contains 0 images.
# The article Mukesh (singer) contains 3 images.
# The article Bert Mehaffy contains 0 images.
# The article Michael J. Desmond contains 0 images.
# The article Fruta Fresca contains 1 images.
# The article List of Prussian finance ministers contains 9 images.
# The article Grafton railway station, Auckland contains 1 images.
# The article Clydes Island contains 0 images.
# The article The Shopping Bag Lady contains 0 images.
# The article Henry Buehman contains 3 images.
# The article 2017 FIBA 3x3 Under-18 Europe Cup contains 0 images.
# The article Lisa Armstrong (writer) contains 0 images.
# The article Karen Dunn contains 1 images.
# The article Reginald Crompton contains 2 images.
# The article Dave Drechsler contains 0 images.
# The article Dunker House contains 2 images.
# The article Casey Hess contains 1 images.
# The article Dale Stoffel contains 1 images.
# The article Ayetoro Gbede contains 1 images.
# The article List of shipwrecks in February 1836 contains 0 images.
# The article Demi-Gods and Semi-Devils (2003 TV series) contains 1 images.
# The article Rzewuski family contains 10 images.
# The article Sichuan women's volleyball team contains 0 images.
# The article Bigeye houndshark contains 3 images.
# The article 1975 NCAA Division I football rankings contains 0 images.
# The article Yarrow boiler contains 8 images.
# The article Hindu Temple of Minnesota contains 1 images.
# The article Tamluk Hamilton High School contains 1 images.
# The article Francis Dane contains 0 images.
# The article Fred Baker (engineer) contains 1 images.
# The article Fraser baronets of Tain (1943) contains 1 images.
# The article Body Riddle contains 1 images.
# The article Spencer Jones (comedian) contains 1 images.
# The article Snow Queen Trophy contains 4 images.
# The article The Heist (album) contains 1 images.
# The article 778 Naval Air Squadron contains 0 images.
# The article Nancy B. Pettit contains 3 images.
# The article Steve Landen contains 0 images.
# The article Hardyman contains 0 images.
# The article 2018 Jalisco Open – Doubles contains 0 images.
# The article Nu Thang contains 1 images.
# The article Meckesheim–Neckarelz railway contains 8 images.
# The article 2015 BMW Open – Singles contains 0 images.
# The article NexTraq contains 0 images.
# The article Chuck Loeb contains 1 images.
# The article Di-tert-butyl-iminodicarboxylate contains 1 images.
# The article Skip Rollins contains 0 images.
# The article Canadian University Field Lacrosse Association contains 6 images.
# The article 2013 Northern Ireland Youth Soccer Tournament contains 0 images.
# The article Stanislas Solaux contains 0 images.
# The article 1973 NSWRFL season contains 12 images.
# The article Maestro concept contains 2 images.
# The article Chabauty topology contains 0 images.
# The article 2003 America East men's basketball tournament contains 0 images.
# The article List of banks in the Philippines contains 0 images.
# The article Theatre in education contains 0 images.
# The article Abar Proloy contains 1 images.
# The article Judd Nelson contains 1 images.
# The article List of cities in Lesotho contains 2 images.
# The article Bácsbokod contains 4 images.
# The article Alan McCullough (architect) contains 0 images.
# The article Sidi Merouane contains 1 images.
# The article New Mexico State Road 252 contains 2 images.
# The article National Route 212 (Costa Rica) contains 1 images.
# The article Rohit Khosla contains 2 images.
# The article Derek Hardiman contains 0 images.
# The article Apocalypse of Simeon Kepha contains 0 images.
# The article Pacific Cycles contains 5 images.
# The article 303rd Intelligence Squadron contains 3 images.
# The article People's Movement for Justice and Welfare contains 0 images.
# The article Saigō, Miyazaki contains 0 images.
# The article Antwerp International Exposition (1894) contains 1 images.
# The article Andrena amphibola contains 0 images.
# The article Dragon's Lair (1990 video game) contains 2 images.
# The article IFK Östersund contains 1 images.
# The article Stored-value card contains 2 images.
# The article Ivo Pantulf contains 0 images.
# The article Jurgen Lentink contains 0 images.
# The article Hobby Center for the Performing Arts contains 5 images.
# The article Bullwhip (film) contains 1 images.
# The article St Clair, Goulburn contains 2 images.
# The article Jolette (singer) contains 0 images.
# The article North County Trailway contains 4 images.
# The article Miss North Dakota USA contains 0 images.
# The article U.S. National Vegetation Classification contains 1 images.
# The article Tirunelveli division contains 0 images.
# The article USS YP-16 contains 1 images.
# The article Spring Branch (Murderkill River tributary) contains 3 images.
# The article Tarence Kinsey contains 1 images.
# The article Papua New Guinea at the 1984 Summer Olympics contains 1 images.
# The article 525th Air Defense Group contains 3 images.
# The article Kabekona Lake contains 1 images.
# The article Zatoichi and the Chest of Gold contains 1 images.
# The article Horsemen Family contains 0 images.
# The article Blepharomastix hedychroalis contains 0 images.
# The article Che sarà contains 0 images.
# The article Eupithecia subcolorata contains 0 images.
# The article Herman Miller (writer) contains 0 images.
# The article Nessel contains 0 images.
# The article Formentera del Segura contains 1 images.
# The article Boules contains 2 images.
# The article Aidan Eames contains 0 images.
# The article Reed Budge contains 1 images.
# The article Jules Verne ATV contains 9 images.
# The article Budziszewo, Kuyavian-Pomeranian Voivodeship contains 1 images.
# The article National Register of Historic Places listings in Boone County, Indiana contains 17 images.
# The article Azure-thighed tree frog contains 0 images.
# The article Michael Weiße contains 0 images.
# The article Deraeocoris flavilinea contains 1 images.
# The article Dialampsis contains 0 images.
# The article South African motorcycle Grand Prix contains 3 images.
# The article John Balistreri contains 1 images.
# The article Great Britain men's national inline hockey team contains 0 images.
# The article Persoonia brevirhachis contains 2 images.
# The article Republican City Township, Harlan County, Nebraska contains 1 images.
# The article Mary Evelyn Rhodes contains 0 images.
# The article Kumaragupta I contains 12 images.
# The article Sooryaputhran contains 0 images.
# The article Darwin College, Cambridge contains 34 images.
# The article Leo Bachle contains 0 images.
# The article Dilektaşı, Genç contains 1 images.
# The article Daktari (album) contains 1 images.
# The article Assi IF contains 1 images.
# The article Laporte Township, Sullivan County, Pennsylvania contains 4 images.
# The article Tezozomoctli (Cuauhtitlan) contains 0 images.
# The article Miami Dolphins Cheerleaders contains 2 images.
# The article Richard Nute contains 0 images.
# The article Gnathopalystes contains 1 images.
# The article Wish me mell contains 1 images.
# The article Hermodice contains 1 images.
# The article Cycloclavine contains 1 images.
# The article Jargalant, Orkhon contains 0 images.
# The article Morten Gunnar Larsen contains 1 images.
# The article Dirty Work (Brown novel) contains 0 images.
# The article Shoilmari River contains 0 images.
# The article Nurzec, Siemiatycze County contains 2 images.
# The article Plemyristis contains 0 images.
# The article New 7 Wonders Cities contains 7 images.
# The article Bank of Mozambique contains 5 images.
# The article Al Haliq Mosque contains 6 images.
# The article Boundary Waters Blues Festival contains 0 images.
# The article Carlos Torre Repetto Memorial contains 1 images.
# The article Massachusetts Route 58 contains 3 images.
# The article Dinner Party Stakes contains 2 images.
# The article Togo at the 2019 African Games contains 1 images.
# The article Iain Finlay contains 0 images.
# The article Ekhtyiarabad-e Do Ziyarati contains 1 images.
# The article Atamestane contains 1 images.
# The article KRI Makassar (590) contains 1 images.
# The article Armando Fragna contains 0 images.
# The article Jim Olsen contains 2 images.
# The article Wallowa Union Railroad Authority contains 1 images.
# The article Willenhall contains 8 images.
# The article Urban Mazanovský contains 0 images.
# The article Mario Chiesa (cyclist) contains 1 images.
# The article Notothixos subaureus contains 0 images.
# The article Hemicrepidius flavipes contains 0 images.
# The article Bartoszówka, Masovian Voivodeship contains 1 images.
# The article Moldova at the 2022 World Athletics Championships contains 1 images.
# The article 1999–2000 EHF Champions League contains 0 images.
# The article International Clinical Trials Registry Platform contains 0 images.
# The article David Rawnsley contains 0 images.
# The article Human Touch (Betty Who song) contains 1 images.
# The article Convoy OG 82 contains 0 images.
# The article Local Government ICT Network contains 1 images.
# The article Best Action Sports Athlete ESPY Award contains 2 images.
# The article Knuckles Nelson contains 0 images.
# The article Scrignac contains 5 images.
# The article Lehigh Line Connection contains 2 images.
# The article Restless legs syndrome contains 1 images.
# The article Hélder Pinheiro contains 0 images.
# The article Kudo-kai contains 1 images.
# The article Volume 8 (Fabrizio De André album) contains 1 images.
# The article Wite-Out contains 0 images.
# The article 1971 SCCA L&M Continental 5000 Championship contains 1 images.
# The article Gaston Étienne contains 0 images.
# The article The End of the Affair? contains 0 images.
# The article Martha Quest contains 1 images.
# The article Congregation of Our Lady of Calvary contains 0 images.
# The article Malú contains 2 images.
# The article 1998 San Diego Chargers season contains 0 images.
# The article John McDuffie contains 4 images.
# The article Front and Centre contains 0 images.
# The article The Dearly Beloved (band) contains 1 images.
# The article Lúcia Teixeira contains 1 images.
# The article Pontevedra, Buenos Aires contains 5 images.
# The article Cowboy Graves contains 1 images.
# The article Flashing Lights (Havana Brown song) contains 1 images.
# The article Glaucostola binotata contains 0 images.
# The article Stefan Güttel contains 0 images.
# The article Gifty Klenam contains 0 images.
# The article Tommy Ritchie contains 0 images.
# The article South Indian Cultural Association, Indore contains 0 images.
# The article Johann Adam Ackermann contains 1 images.
# The article Martha Merrow contains 0 images.
# The article Darkhorse Theater contains 0 images.
# The article Hans Eskilsson contains 0 images.
# The article Yitzhak Sadeh Prize contains 0 images.
# The article Lorely Burt contains 1 images.
# The article Malcolm Lindsay contains 0 images.
# The article Cornellà del Terri contains 5 images.
# The article Hybrid iguana contains 1 images.
# The article The Golf House Club contains 4 images.
# The article Trichoxys atripes contains 0 images.
# The article Joiner (surname) contains 0 images.
# The article Hornnes Church contains 8 images.
# The article Dewan Farid Gazi contains 1 images.
# The article Mary Worth contains 3 images.
# The article Monaco at the Olympics contains 1 images.
# The article Zubaida al-Meeki contains 0 images.
# The article Maximina Uepa contains 1 images.
# The article Living (1954 TV program) contains 0 images.
# The article Uzbekistan Professional Football League contains 1 images.
# The article Adelle Davis contains 1 images.
# The article Hudson, Wisconsin contains 7 images.
# The article Rosa 'La France' contains 2 images.
# The article Judo at the 2014 Commonwealth Games – Men's 81 kg contains 1 images.
# The article Arizona's 5th legislative district contains 4 images.
# The article James Drake (politician) contains 6 images.
# The article Tulak (Golden Horde) contains 0 images.
# The article Abigail Adams Smith contains 5 images.
# The article Kayraly contains 3 images.
# The article Union Church, Nuwara Eliya contains 1 images.
# The article Xiong Zhi contains 0 images.
# The article If Only It Were True contains 1 images.
# The article Bukowo, Sztum County contains 1 images.
# The article Kitasen Dam contains 1 images.
# The article Egon Wisniowski contains 1 images.
# The article Grabowno Małe contains 1 images.
# The article Fred Ivimey contains 0 images.
# The article Juba (footballer, born 1984) contains 0 images.
# The article Gus J. Solomon United States Courthouse contains 7 images.
# The article Teychenné contains 0 images.
# The article Hajra Khan (actress) contains 0 images.
# The article Tlachene Cove contains 1 images.
# The article Palaquium vexillatum contains 0 images.
# The article 1886 in the United Kingdom contains 0 images.
# The article Mami Kosuge contains 0 images.
# The article Peter Karia contains 0 images.
# The article Ansha, Changsha contains 3 images.
# The article 63rd Golden Globe Awards contains 13 images.
# The article A Cup of Coffee and New Shoes On contains 1 images.
# The article 2006 United States House of Representatives election in the District of Columbia contains 4 images.
# The article Sirəbil contains 2 images.
# The article Jean Perron contains 0 images.
# The article List of awards and nominations received by Terry Pratchett contains 2 images.
# The article Gulfstream G400/G500/G600 contains 7 images.
# The article IvyGate contains 2 images.
# The article Janro van Niekerk contains 0 images.
# The article Rusudan contains 0 images.
# The article Hi-Tech Medical College & Hospital, Bhubaneswar contains 2 images.
# The article Les Rohr contains 0 images.
# The article Pınarbaşı, Ortaköy contains 0 images.
# The article Magomet Isayev contains 0 images.
# The article Phases and Stages contains 2 images.
# The article Wiki Loves Pride contains 2 images.
# The article Queen's University Faculty of Law contains 1 images.
# The article Pioneer State High School contains 1 images.
# The article Elachista bregorella contains 0 images.
# The article Stem Player contains 1 images.
# The article Dazhai contains 2 images.
# The article Süleyman Nazif contains 2 images.
# The article Mihrak contains 1 images.
# The article Jack Roos contains 0 images.
# The article Home Alone (song) contains 1 images.
# The article Kazis and Thikadars of Sikkim contains 0 images.
# The article Doping at the 1998 Tour de France contains 2 images.
# The article Zion Ozeri contains 0 images.
# The article Finnish II Corps (Winter War) contains 0 images.
# The article Győr-Moson-Sopron County 1st constituency contains 1 images.
# The article Athletics at the 1995 Pan American Games – Men's 200 metres contains 0 images.
# The article Jagdstaffel 34 contains 1 images.
# The article Morgan ab Athrwys contains 0 images.
# The article Ardozyga loemias contains 0 images.
# The article Old Salem, Alabama contains 3 images.
# The article Mars 2MV-4 No.1 contains 3 images.
# The article Caloptilia glyphidopis contains 0 images.
# The article Julia Faye contains 5 images.
# The article Raa (surname) contains 0 images.
# The article Bubble light contains 5 images.
# The article Laurie Shrage contains 0 images.
# The article Charles McGee (pilot) contains 9 images.
# The article Zac Smith contains 1 images.
# The article Elizabeth Wellesley, Duchess of Wellington contains 1 images.
# The article Thomas Erskine (judge) contains 0 images.
# The article 2022 ICF Canoe Sprint World Championships – Men's VL1 contains 0 images.
# The article 2023 East Africa T20 Cup contains 0 images.
# The article List of wars involving the United Arab Emirates contains 0 images.
# The article 89th (Princess Victoria's) Regiment of Foot contains 3 images.
# The article El Cerrito, San Diego contains 1 images.
# The article Alan R. Graham contains 1 images.
# The article Parudur contains 1 images.
# The article Killian Brady contains 0 images.
# The article Cnemacantha contains 0 images.
# The article APOPO contains 1 images.
# The article Danish Clothing and Textile Workers' Union contains 0 images.
# The article Super Love (Dami Im song) contains 1 images.
# The article Matanglawin (publication) contains 1 images.
# The article Henneicke Column contains 0 images.
# The article Spotted thicklip loach contains 2 images.
# The article Ceratinia tutia contains 1 images.
# The article James Gordon, 2nd Viscount Aboyne contains 0 images.
# The article Yongsan District contains 15 images.
# The article Selim District contains 3 images.
# The article Bayard 1908 contains 1 images.
# The article Abigail Fallis contains 1 images.
# The article Villalcampo contains 3 images.
# The article Glad Rags (TV series) contains 0 images.
# The article Remains (Annihilator album) contains 1 images.
# The article Richard Peck (RAF officer) contains 1 images.
# The article Frederic Carpenter Skey contains 2 images.
# The article Else Gebel contains 0 images.
# The article Cleo Smith (baseball) contains 0 images.
# The article Abil Pol Randeh contains 0 images.
# The article Thomas R. Adams contains 0 images.
# The article Live at the Jazz Standard (André Previn album) contains 1 images.
# The article G-fibration contains 0 images.
# The article Angacha contains 0 images.
# The article Howe Sound Crest Trail contains 1 images.
# The article Thak man-eater contains 1 images.
# The article East 79th station (GCRTA Blue and Green Lines) contains 2 images.
# The article Inside the NFL contains 0 images.
# The article Randall G. Hulet contains 0 images.
# The article Ayats Bravo contains 4 images.
# The article David Fitzsimmons contains 0 images.
# The article Albert Chester contains 0 images.
# The article Feras Saied contains 0 images.
# The article Winniki, West Pomeranian Voivodeship contains 2 images.
# The article Naya, Myanmar contains 1 images.
# The article Xyletobius mimus contains 0 images.
# The article Prasophyllinae contains 1 images.
# The article Colin McDonald (New Zealand cricketer) contains 0 images.
# The article Bulls Head Ground contains 1 images.
# The article San Vicente de León contains 0 images.
# The article OpenShift contains 1 images.
# The article Şoray Uzun contains 0 images.
# The article Brunei at the 2022 Commonwealth Games contains 1 images.
# The article Ciro Berardi contains 0 images.
# The article Turbo haynesi contains 0 images.
# The article Samuel Mattocks contains 0 images.
# The article Perth (provincial electoral district) contains 0 images.
# The article Alanna O'Kelly contains 0 images.
# The article Émile Masson Jr. contains 0 images.
# The article Birgit Anette Olsen contains 0 images.
# The article In These Silent Days contains 2 images.
# The article WORJ-LP contains 1 images.
# The article Kepi contains 29 images.
# The article Mass Hysteria (band) contains 1 images.
# The article On Your Back contains 1 images.
# The article Giovanni Battista Antici contains 0 images.
# The article Order of Mwalimu Julius Kambarage Nyerere contains 0 images.
# The article 2001–02 FA Premier League contains 5 images.
# The article List of faculties of law in France contains 0 images.
# The article Blue Water (train) contains 4 images.
# The article Bobby Rogers contains 2 images.
# The article Send for Me contains 1 images.
# The article Betty Beath contains 1 images.
# The article List of members of the European Parliament for Portugal, 2014–2019 contains 0 images.
# The article Ribonuclease T2 contains 0 images.
# The article Yeşilbük, Şiran contains 1 images.
# The article 107th Rocket Brigade (Russia) contains 2 images.
# The article Titus Awotwi Pratt contains 0 images.
# The article Rutledge Dennis contains 3 images.
# The article Adultery in English law contains 1 images.
# The article What She Wants Tonight contains 1 images.
# The article Rullestad Tunnel contains 1 images.
# The article Odometry contains 1 images.
# The article Alexander Rüstow contains 2 images.
# The article Gantz (film) contains 1 images.
# The article Israel Resilience Party contains 2 images.
# The article Dancing on Ice contains 1 images.
# The article Zaō Quasi-National Park contains 4 images.
# The article Hypatima dermatica contains 0 images.
# The article Slovenian Futsal Cup contains 0 images.
# The article Himangshu Mohan Choudhury contains 0 images.
# The article Maximillian Wood contains 1 images.
# The article Alfons Jeżewski contains 0 images.
# The article Aapsta contains 2 images.
# The article Bingo Stadium contains 2 images.
# The article Kira Soltanovich contains 0 images.
# The article Modern Welding Company, Inc. contains 0 images.
# The article Shunpei contains 0 images.
# The article Henry Kiel contains 2 images.
# The article Seganfredo contains 0 images.
# The article The Quest for the Historical Muhammad contains 1 images.
# The article Sammy Figueroa contains 0 images.
# The article Yaa Asantewaa Festival contains 0 images.
# The article Gunn Marit Helgesen contains 1 images.
# The article Therese Soukup contains 0 images.
# The article HMS Preston contains 0 images.
# The article Parastagmatoptera zernyi contains 0 images.
# The article Faders Up 2 contains 0 images.
# The article Prix République du Glamour contains 0 images.
# The article 15 cm sIG 33 auf Fahrgestell Panzerkampfwagen II (Sf) contains 2 images.
# The article Hu Mingyuan contains 0 images.
# The article Hot Pink (The Pink Spiders album) contains 1 images.
# The article La Rambla, Barcelona contains 8 images.
# The article C.W. Downer & Co. contains 1 images.
# The article Frank Figueroa contains 0 images.
# The article Legal education in Sri Lanka contains 0 images.
# The article One Thing at a Time contains 1 images.
# The article Arthur Huddleston contains 0 images.
# The article Cheshire, Connecticut contains 15 images.
# The article 2017 in Myanmar contains 3 images.
# The article Scarface (Push It to the Limit) contains 1 images.
# The article Halos for Heros, Dirt for the Dead contains 1 images.
# The article Kerry Mitchell contains 1 images.
# The article Regas contains 0 images.
# The article Segunda División Player of the Month contains 2 images.
# The article Pratibha Advani contains 0 images.
# The article The Only Number That Matters Is Won contains 1 images.
# The article Arodys Vizcaíno contains 2 images.
# The article Olsza, Greater Poland Voivodeship contains 1 images.
# The article Athyrtis contains 1 images.
# The article Billy Edwin Reid contains 1 images.
# The article 2014 World Junior Championships in Athletics – Women's 800 metres contains 0 images.
# The article Big Canoe contains 1 images.
# The article Tyari contains 4 images.
# The article Stari Broskivtsi contains 0 images.
# The article Diana Fleischman contains 2 images.
# The article Dryophilus pusillus contains 1 images.
# The article 1700s in literature contains 0 images.
# The article Dipeptide contains 3 images.
# The article 1967 PGA Tour Qualifying School graduates contains 0 images.
# The article Myrthen contains 1 images.
# The article Jefferson Cuero contains 0 images.
# The article Parker Cleaveland House contains 3 images.
# The article Vranješ contains 0 images.
# The article 1986–87 Illinois State Redbirds men's basketball team contains 1 images.
# The article Franz Kröwerath contains 0 images.
# The article List of Statutory Rules of Northern Ireland, 2020 contains 1 images.
# The article Are We Dating The Same Guy? contains 0 images.
# The article Cannabis in China contains 1 images.
# The article 119th Infantry Division (German Empire) contains 0 images.
# The article Shilton, Warwickshire contains 2 images.
# The article Tireli, Mali contains 9 images.
# The article Bernhard Haurwitz contains 0 images.
# The article Al Bayda Stadium contains 2 images.
# The article Margaret Chase Smith contains 7 images.
# The article Mordellistena wagneri contains 0 images.
# The article A. G. Sulzberger contains 1 images.
# The article Münzenberg (surname) contains 0 images.
# The article TKO (Le Tigre song) contains 1 images.
# The article Vassfaret contains 9 images.
# The article Christine Nakwang Tubo contains 0 images.
# The article The Little Nugget contains 1 images.
# The article McLeod Building contains 4 images.
# The article China Girl (1987 film) contains 1 images.
# The article George True Bartlett contains 1 images.
# The article Constantin Agiu contains 2 images.
# The article Susenphaa contains 1 images.
# The article Weem (album) contains 1 images.
# The article Fawn River (Michigan) contains 1 images.
# The article Communist Party of Turkey (Workers Voice) contains 1 images.
# The article Sutton Coldfield (UK Parliament constituency) contains 3 images.
# The article 1988 Roller Hockey World Cup contains 1 images.
# The article Bowyer's Common contains 1 images.
# The article Dienst contains 0 images.
# The article Yoon Je-kyoon contains 1 images.
# The article Khajuha contains 2 images.
# The article Genetic representation contains 0 images.
# The article Symi contains 21 images.
# The article St Andrew's Church, High Ham contains 5 images.
# The article Rore, Glamoč contains 1 images.
# The article Broström procedure contains 0 images.
# The article Emily Chalker contains 1 images.
# The article Nikolsky, Altai Krai contains 2 images.
# The article One of a Kind (Love Affair) contains 1 images.
# The article Freudy Cat contains 0 images.
# The article Chocolate Factory contains 1 images.
# The article Yuraq Urqu (Bolivia) contains 2 images.
# The article Mystery (novel) contains 1 images.
# The article Zakępie, Lublin Voivodeship contains 2 images.
# The article When Louis Met... contains 1 images.
# The article Epidemas cinerea contains 0 images.
# The article 2006–07 ECHL season contains 0 images.
# The article Jose Martinez (boxer) contains 0 images.
# The article Flămânda Church contains 1 images.
# The article James Cosmano contains 0 images.
# The article Indian rupee sign contains 4 images.
# The article Companies listed on the New York Stock Exchange (T) contains 0 images.
# The article Get the Picture (game show) contains 1 images.
# The article Vladimir Poulnikov contains 1 images.
# The article Lanthanum oxalate contains 0 images.
# The article South (lunar crater) contains 1 images.
# The article America in Vietnam contains 0 images.
# The article Maritime Museum of San Diego contains 8 images.
# The article A Dónde contains 1 images.
# The article Eoacmaea javanica contains 0 images.
# The article Taşgedik, Ömerli contains 1 images.
# The article Jikharra contains 1 images.
# The article Bhawanipatna contains 13 images.
# The article Scott Lipton contains 0 images.
# The article Vaishali Desai contains 1 images.
# The article Perspex Island contains 1 images.
# The article Fokker D.XI contains 2 images.
# The article Daijee contains 2 images.
# The article Khary Payton contains 1 images.
# The article Insect repellent contains 7 images.
# The article Dâu Temple contains 2 images.
# The article Joy Compressor contains 0 images.
# The article Christer Källén contains 0 images.
# The article Laid-Back Camp Movie contains 2 images.
# The article Andrew Greig contains 0 images.
# The article Blood in the Water match contains 1 images.
# The article East and West Africa Medal contains 2 images.
# The article Venugopal contains 0 images.
# The article Once Upon a Time Twenty Years Later contains 0 images.
# The article You Are My Sunshine (2015 film) contains 1 images.
# The article Angola at the 2020 Summer Olympics contains 1 images.
# The article Readme.cc contains 0 images.
# The article Chile at the 2009 World Championships in Athletics contains 1 images.
# The article Microsoft Flight Simulator X contains 1 images.
# The article Madeleine Madden contains 1 images.
# The article Hypexilis longipennis contains 0 images.
# The article Iguerali contains 1 images.
# The article Fire police contains 0 images.
# The article Paulina Is Leaving contains 1 images.
# The article Francesco Lamon contains 1 images.
# The article Eocarcharia contains 16 images.
# The article 1920 Spring Hill Badgers football team contains 0 images.
# The article 2015–16 Western Kentucky Lady Toppers basketball team contains 1 images.
# The article John Joseph Woods contains 1 images.
# The article Kosovo Dabje contains 1 images.
# The article Legacy High School (South Gate, California) contains 1 images.
# The article Kadoma, Osaka contains 8 images.
# The article Warwick Films contains 0 images.
# The article Justo Somonte Iturrioz contains 0 images.
# The article Robert Brackenbury contains 0 images.
# The article The Applejacks (American band) contains 0 images.
# The article Steve McQueen contains 8 images.
# The article Krasnaya Nunatak contains 0 images.
# The article The Pines (Anniston, Alabama) contains 3 images.
# The article 1993 Ukrainian Women's League contains 2 images.
# The article Jabbar Baghtcheban contains 1 images.

# %%
sns.scatterplot(data=df, x="Article_Name", y = "Article_Image_Count")
# Out:
# <AxesSubplot:xlabel='Article_Name', ylabel='Article_Image_Count'>

# %%
for i in range(len(df)):
    if
# Out:
# 109.0

# %%
sns.histplot(df['Article_Image_Count'], kde=True, binwidth=1)

# Add labels and title
plt.xlabel('Number of Images')
plt.ylabel('Number of Articles')
plt.title('Distribution of Articles by Number of Images')
plt.xlim(0, 15)
# Show the plot
plt.show()

# %%
df['Article_Image_Count'].mean()
# Out:
# 1.854

# %%
df['Article_Image_Count'].median()
# Out:
# 1.0

# %%
max_image_count_row = df.loc[df['Article_Image_Count'].idxmax()]

# Extract the article name from the row
article_name_with_most_images = max_image_count_row['Article_Name']
article_name_with_most_images
# Out:
# 'Beresford Stakes'

# %%
max_image_count_row['Article_Image_Count']
# Out:
# 109.0
